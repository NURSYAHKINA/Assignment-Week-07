# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 752.0 kB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.13.2 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (3.7.0)
# Requirement already satisfied: setuptools in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (65.6.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\nursy\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nursy\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nursy\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nursy\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\nursy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.6)
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)

# %%
apriori(df, min_support=0.6, use_colnames=True)
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Onion, Eggs, Kidney Beans)

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                     itemsets  length
# 0       0.8                       (Eggs)       1
# 1       1.0               (Kidney Beans)       1
# 2       0.6                       (Milk)       1
# 3       0.6                      (Onion)       1
# 4       0.6                     (Yogurt)       1
# 5       0.8         (Eggs, Kidney Beans)       2
# 6       0.6                (Onion, Eggs)       2
# 7       0.6         (Milk, Kidney Beans)       2
# 8       0.6        (Onion, Kidney Beans)       2
# 9       0.6       (Yogurt, Kidney Beans)       2
# 10      0.6  (Onion, Eggs, Kidney Beans)       3

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.8) ]
# Out:
#    support              itemsets  length
# 5      0.8  (Eggs, Kidney Beans)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'Onion', 'Eggs'} ]
# Out:
#    support       itemsets  length
# 6      0.6  (Onion, Eggs)       2

# %%
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
sparse_df = pd.DataFrame.sparse.from_spmatrix(oht_ary, columns=te.columns_)
sparse_df
# Out:
#    Apple  Corn  Dill  Eggs  Ice cream  Kidney Beans  Milk  Nutmeg  Onion  \
# 0      0     0     0     1          0          True     1       1      1
# 1      0     0     1     1          0          True     0       1      1
# 2      1     0     0     1          0          True     1       0      0
# 3      0     1     0     0          0          True     1       0      0
# 4      0     1     0     1          1          True     0       0      1
#
#    Unicorn  Yogurt
# 0        0       1
# 1        0       1
# 2        0       0
# 3        1       1
# 4        0       0

# %%
apriori(sparse_df, min_support=0.6, use_colnames=True, verbose=1)
# Out:
# Processing 21 combinations | Sampling itemset size 3
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Onion, Eggs, Kidney Beans)

# %%
Processing 21 combinations | Sampling itemset size 3
# Out:
#   Cell In[11], line 1
#     Processing 21 combinations | Sampling itemset size 3
#                ^
# SyntaxError: invalid syntax

# %%
apriori(df, min_support=0.5, use_colnames=False, max_len=None, verbose=0, low_memory=False)
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)
